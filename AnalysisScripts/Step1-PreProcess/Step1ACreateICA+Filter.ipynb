# %%
import mne, os, glob
import numpy as np
from joblib import Parallel, delayed
"""Script to create and save ICA fif files for later examination and removal, and filter the data using
a notch filter + a high pass filter"""

# Set base of bids directory here
bids_top_dir = '/System/Volumes/Data/misc/data12/sjapee/Sebastian-OrientationImagery/Data/Bids/bids_dir/'
def load_raw(bids_dir, subjid, session_nr, run_nr, add_dynamic=False):
    "Load raw data"
    task_name = 'OrientationImageryDynamic' if add_dynamic else 'OrientationImagery'
    raw_fn = f'{bids_dir}/sub-{subjid}/ses-{session_nr}/meg/sub-{subjid}_ses-{session_nr}_task-{task_name}_run-{str(run_nr).zfill(2)}_meg.ds'
    raw = mne.io.read_raw_ctf(raw_fn, system_clock='ignore', preload=True)
    return raw, raw_fn


def filter(raw):
    "Filter out mainline frequency data, and apply a high pass filter for frequencies below .5 Hz"
    raw.notch_filter(np.arange(60, 241, 60), phase='zero-double', fir_design='firwin2')
    raw.filter(l_freq=0.5, h_freq=None)
    return raw

def ica(raw, bids_dir, raw_fn, add_dynamic=False):
    "Apply ICA to the raw data and save out the ICA files for later examination, plus save out the filtered raw data"
    ica = mne.preprocessing.ICA(n_components=20, noise_cov=None, random_state=1, 
                                method='fastica', fit_params=None, max_iter='auto', allow_ref_meg=False, verbose=None)
    ica.fit(raw)
    out_dir = f"/System/Volumes/Data/misc/data12/sjapee/Sebastian-OrientationImagery/Data/Bids/derivatives/preprocessed/ICA/"
    os.makedirs(out_dir, exist_ok=True)
    
    base = raw_fn.split('/')[-1][:-7]
    
    ica.save(f"{out_dir}{base}_step1a-ica.fif", overwrite=True)
    raw.save(f"{out_dir}{base}_step1a-raw.fif", overwrite=True)


def run_ica(bids_dir, subjid, session_nr, run_nr, add_dynamic=False):
    "Run through the process of loading data, events, cropping, filtering, and running ICA"
    raw, raw_fn = load_raw(bids_dir, subjid, session_nr, run_nr, add_dynamic=add_dynamic)
    events = mne.events_from_annotations(raw)
    print('events', events)
    print('times', len(raw.times))
    raw.crop(0,raw.times[events[0][-1,0]]+4)
    raw = filter(raw)
    ica(raw, bids_dir, raw_fn, add_dynamic=add_dynamic)


#*****************************#
### Run Script ###
#*****************************#
subjects = [f"S{i:02}" for i in range(1, 21)]
for subject in subjects:
    subjid = subject
    session_nr = '1'

    bids_dir = bids_top_dir.rstrip('/')  
    dsets = []
    #Loop for still runs
    for i in range(1, 5):  
        ds = f'run-{i:02}'
        pattern = f'{bids_dir}/sub-{subjid}/ses-{session_nr}/meg/sub-{subjid}_ses-{session_nr}_task-OrientationImagery_{ds}_meg.ds'
        matches = glob.glob(pattern)
        if matches:
            dsets.append(i)
        else:
            print(f"No files found for pattern: {pattern}")

    print("Datasets to process:", dsets)
    for run_nr in dsets:
        run_ica(bids_dir, subjid, session_nr, run_nr, add_dynamic=False)
    Parallel(n_jobs=12, backend="loky")(
        delayed(run_ica)(bids_dir, subjid, session_nr, run_nr, add_dynamic=False) for run_nr in dsets
    )

    #Loop for Dynamic runs
    dsets = []
    for i in range(1, 5):  
        ds = f'run-{i:02}'
        pattern = f'{bids_dir}/sub-{subjid}/ses-{session_nr}/meg/sub-{subjid}_ses-{session_nr}_task-OrientationImageryDynamic_{ds}_meg.ds'
        matches = glob.glob(pattern)
        if matches:
            dsets.append(i)
        else:
            print(f"No files found for pattern: {pattern}")

    print("Datasets to process:", dsets)

    # Run ICA on available datasets
    Parallel(n_jobs=12, backend="loky")(
        delayed(run_ica)(bids_dir, subjid, session_nr, run_nr, add_dynamic=True) for run_nr in dsets
    )
# Out:
# Datasets to process: [4]
# ds directory : /System/Volumes/Data/misc/data12/sjapee/Sebastian-OrientationImagery/Data/Bids/bids_dir/sub-S04/ses-1/meg/sub-S04_ses-1_task-OrientationImageryDynamic_run-04_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        1.67   64.50    0.00 mm <->    1.67   64.50    0.00 mm (orig :  -37.93   58.24 -252.05 mm) diff =    0.000 mm
#       -1.67  -64.50    0.00 mm <->   -1.67  -64.50    0.00 mm (orig :   62.91  -21.87 -260.16 mm) diff =    0.000 mm
#       79.79    0.00    0.00 mm <->   79.79    0.00    0.00 mm (orig :   55.17   70.98 -214.17 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /System/Volumes/Data/misc/data12/sjapee/Sebastian-OrientationImagery/Data/Bids/bids_dir/sub-S04/ses-1/meg/sub-S04_ses-1_task-OrientationImageryDynamic_run-04_meg.ds/sub-S04_ses-1_task-OrientationImageryDynamic_run-04_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 311 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
# Used Annotations descriptions: ['S01/Dynamic/0022_Left', 'S01/Dynamic/0022_Right', 'S01/Dynamic/0067_Left', 'S01/Dynamic/0067_Right', 'S01/Dynamic/0112_Left', 'S01/Dynamic/0112_Right', 'S01/Dynamic/0157_Left', 'S01/Dynamic/0157_Right', 'S01/Dynamic/0202_Left', 'S01/Dynamic/0202_Right', 'S01/Dynamic/0247_Left', 'S01/Dynamic/0247_Right', 'S01/Dynamic/0292_Left', 'S01/Dynamic/0292_Right', 'S01/Dynamic/0337_Left', 'S01/Dynamic/0337_Right', 'S01/Dynamic/catch']
# events (array([[  1746,      0,      8],
#        [  5986,      0,     11],
#        [ 10266,      0,      1],
#        [ 14565,      0,      3],
#        [ 18845,      0,     16],
#        [ 23065,      0,     14],
#        [ 27345,      0,      4],
#        [ 31644,      0,      6],
#        [ 35904,      0,     12],
#        [ 40184,      0,     13],
#        [ 45943,      0,      7],
#        [ 50183,      0,      5],
#        [ 54403,      0,      2],
#        [ 58643,      0,     15],
#        [ 62862,      0,      9],
#        [ 67122,      0,     10],
#        [ 71402,      0,      4],
#        [ 75641,      0,     13],
#        [ 79941,      0,     12],
#        [ 84181,      0,     17],
#        [ 88961,      0,      2],
#        [ 94760,      0,      7],
#        [ 99060,      0,     14],
#        [103360,      0,      3],
#        [107599,      0,      9],
#        [111859,      0,     11],
#        [116119,      0,     15],
#        [120419,      0,     16],
#        [124658,      0,     10],
#        [128878,      0,     17],
#        [133718,      0,      8],
#        [137937,      0,      6],
#        [143497,      0,      5],
#        [147757,      0,      1],
#        [151997,      0,      3],
#        [156216,      0,     14],
#        [160436,      0,      4],
#        [164696,      0,      5],
#        [168995,      0,     12],
#        [173295,      0,     17],
#        [178075,      0,     10],
#        [182375,      0,      9],
#        [186654,      0,      8],
#        [192394,      0,      2],
#        [196614,      0,     16],
#        [200913,      0,     15],
#        [205213,      0,     13],
#        [209433,      0,     11],
#        [213733,      0,     17],
#        [218552,      0,      6],
#        [222772,      0,      7],
#        [227052,      0,      1],
#        [231291,      0,      7],
#        [235551,      0,      6],
#        [242971,      0,     16],
#        [247230,      0,     13],
#        [251530,      0,      2],
#        [255750,      0,     14],
#        [260030,      0,     11],
#        [264269,      0,     17],
#        [269029,      0,     12],
#        [273309,      0,      9],
#        [277608,      0,      8],
#        [281848,      0,      3],
#        [286148,      0,      5],
#        [291847,      0,     10],
#        [296067,      0,     15],
#        [300347,      0,      4],
#        [304587,      0,      1],
#        [308806,      0,     17],
#        [313606,      0,     12],
#        [317886,      0,     15],
#        [322185,      0,     11],
#        [326425,      0,      7],
#        [330645,      0,      1],
#        [334865,      0,     14],
#        [342884,      0,     16],
#        [347184,      0,      4],
#        [351464,      0,      5],
#        [355763,      0,     17],
#        [360563,      0,     10],
#        [364783,      0,     13],
#        [369002,      0,      3],
#        [373222,      0,      2],
#        [377482,      0,      6],
#        [381782,      0,      8],
#        [386061,      0,      9],
#        [392041,      0,      5],
#        [396261,      0,     11],
#        [400480,      0,     12],
#        [404700,      0,     17],
#        [409520,      0,      7],
#        [413780,      0,      8],
#        [418079,      0,      2],
#        [422299,      0,      4],
#        [426559,      0,      6],
#        [430858,      0,     10],
#        [435118,      0,     16],
#        [440838,      0,      1],
#        [445058,      0,     15],
#        [449297,      0,     13],
#        [453537,      0,     17],
#        [458377,      0,      3],
#        [462676,      0,      9],
#        [466936,      0,     14],
#        [471156,      0,     14],
#        [475436,      0,     13],
#        [479655,      0,      1],
#        [483895,      0,      7],
#        [490575,      0,     10],
#        [494814,      0,     12],
#        [499034,      0,     17],
#        [503854,      0,      9],
#        [508073,      0,      6],
#        [512373,      0,     11],
#        [516673,      0,     15],
#        [520933,      0,      4],
#        [525192,      0,      5],
#        [529432,      0,      2],
#        [533712,      0,      8],
#        [537991,      0,      3],
#        [542271,      0,     16]]), {'S01/Dynamic/0022_Left': 1, 'S01/Dynamic/0022_Right': 2, 'S01/Dynamic/0067_Left': 3, 'S01/Dynamic/0067_Right': 4, 'S01/Dynamic/0112_Left': 5, 'S01/Dynamic/0112_Right': 6, 'S01/Dynamic/0157_Left': 7, 'S01/Dynamic/0157_Right': 8, 'S01/Dynamic/0202_Left': 9, 'S01/Dynamic/0202_Right': 10, 'S01/Dynamic/0247_Left': 11, 'S01/Dynamic/0247_Right': 12, 'S01/Dynamic/0292_Left': 13, 'S01/Dynamic/0292_Right': 14, 'S01/Dynamic/0337_Left': 15, 'S01/Dynamic/0337_Right': 16, 'S01/Dynamic/catch': 17})
# times 1200000
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandstop filter:
# - Windowed frequency-domain design (firwin2) method
# - Hamming window
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 15840 samples (13.200 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    4.6s
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 7921 samples (6.601 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    4.1s
# Fitting ICA to data using 269 channels (please be patient, this may take a while)
# Removing 5 compensators from info because not all compensation channels were picked.
# Selecting by number: 20 components
# Fitting ICA took 21.6s.
# Writing ICA solution to /System/Volumes/Data/misc/data12/sjapee/Sebastian-OrientationImagery/Data/Bids/derivatives/preprocessed/ICA/sub-S04_ses-1_task-OrientationImageryDynamic_run-04_step1a-ica.fif...
# Writing /System/Volumes/Data/misc/data12/sjapee/Sebastian-OrientationImagery/Data/Bids/derivatives/preprocessed/ICA/sub-S04_ses-1_task-OrientationImageryDynamic_run-04_step1a-raw.fif
# Closing /System/Volumes/Data/misc/data12/sjapee/Sebastian-OrientationImagery/Data/Bids/derivatives/preprocessed/ICA/sub-S04_ses-1_task-OrientationImageryDynamic_run-04_step1a-raw.fif
# [done]

# %%
import mne, os, glob
import numpy as np
from joblib import Parallel, delayed

"""Script to check MEG sensors and identify missing ones."""

def load_raw(bids_dir, subjid, session_nr, run_nr, add_dynamic=False):
    "Load raw data"
    task_name = 'OrientationImageryDynamic' if add_dynamic else 'OrientationImagery'
    raw_fn = f'{bids_dir}/sub-{subjid}/ses-{session_nr}/meg/sub-{subjid}_ses-{session_nr}_task-{task_name}_run-{str(run_nr).zfill(2)}_meg.ds'
    raw = mne.io.read_raw_ctf(raw_fn, system_clock='ignore', preload=True)
    return raw, raw_fn

# -------------------------
# Main loop
# -------------------------
subjects = [f"S{i:02}" for i in range(1, 21)]
for subject in subjects:
    if subject == 'S03' or subject == 'S05':
        continue  # Skip subject S03 due to known data issues
    subjid = subject
    session_nr = '1'
    run_nr = 1  # example run number
    bids_dir = '/Users/sm6511/Desktop/NIH_Experiment/Bids'

    raw, raw_fn = load_raw(bids_dir, subjid, session_nr, run_nr)

    # --- Count MEG sensors ---
    meg_picks = mne.pick_types(raw.info, meg=True, eeg=False, ref_meg=False)
    ref_meg_picks = mne.pick_types(raw.info, meg=False, ref_meg=True)

    print(f"\n{subjid} run-{run_nr:02} ({'Dynamic' if True else 'Still'})")
    print(f"  Total MEG sensors: {len(meg_picks)}")
    print(f"  Reference MEG sensors: {len(ref_meg_picks)}")

    # --- Identify missing sensors ---
    all_meg_chs = [ch for ch in raw.ch_names if 'M' in ch]  # CTF MEG channels start with M
    expected_meg_chs = [f"M{str(i).zfill(3)}" for i in range(1, 276)]  # expected 275 sensors
    missing_chs = [ch for ch in expected_meg_chs if ch not in all_meg_chs]

    if missing_chs:
        print(f"  ⚠️ Missing sensors ({len(missing_chs)}): {missing_chs}")
    else:
        print("  ✅ No missing MEG sensors detected.")

    # --- Check if any are marked bad ---
    if raw.info["bads"]:
        print(f"  Bad channels: {raw.info['bads']}")
# Out:
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S01/ses-1/meg/sub-S01_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.75   71.65    0.00 mm <->    3.75   71.65   -0.00 mm (orig :  -41.24   60.00 -249.05 mm) diff =    0.000 mm
#       -3.75  -71.65    0.00 mm <->   -3.75  -71.65   -0.00 mm (orig :   56.29  -45.24 -250.55 mm) diff =    0.000 mm
#       89.55    0.00    0.00 mm <->   89.55   -0.00    0.00 mm (orig :   68.70   70.21 -231.63 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S01/ses-1/meg/sub-S01_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S01_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S01 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S02/ses-1/meg/sub-S02_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        0.18   74.40    0.00 mm <->    0.18   74.40    0.00 mm (orig :  -45.50   59.08 -257.89 mm) diff =    0.000 mm
#       -0.18  -74.40    0.00 mm <->   -0.18  -74.40    0.00 mm (orig :   59.01  -46.69 -251.95 mm) diff =    0.000 mm
#       90.89    0.00    0.00 mm <->   90.89   -0.00   -0.00 mm (orig :   70.18   69.92 -241.57 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S02/ses-1/meg/sub-S02_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S02_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S02 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S04/ses-1/meg/sub-S04_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        1.22   64.10    0.00 mm <->    1.22   64.10   -0.00 mm (orig :  -38.06   56.72 -251.75 mm) diff =    0.000 mm
#       -1.22  -64.10    0.00 mm <->   -1.22  -64.10   -0.00 mm (orig :   60.65  -24.77 -259.32 mm) diff =    0.000 mm
#       75.01    0.00    0.00 mm <->   75.01   -0.00   -0.00 mm (orig :   55.50   69.03 -226.26 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S04/ses-1/meg/sub-S04_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S04_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S04 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S06/ses-1/meg/sub-S06_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        1.93   76.47    0.00 mm <->    1.93   76.47   -0.00 mm (orig :  -40.88   69.36 -254.04 mm) diff =    0.000 mm
#       -1.93  -76.47    0.00 mm <->   -1.93  -76.47   -0.00 mm (orig :   63.64  -41.14 -270.36 mm) diff =    0.000 mm
#       82.92    0.00    0.00 mm <->   82.92    0.00    0.00 mm (orig :   70.06   69.85 -244.20 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S06/ses-1/meg/sub-S06_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S06_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S06 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S07/ses-1/meg/sub-S07_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#      -15.59   57.44    0.00 mm <->  -15.59   57.44    0.00 mm (orig :   58.01  -50.24 -259.92 mm) diff =    0.000 mm
#       15.59  -57.44    0.00 mm <->   15.59  -57.44    0.00 mm (orig :   85.72   61.90 -231.19 mm) diff =    0.000 mm
#      120.75    0.00    0.00 mm <->  120.75    0.00    0.00 mm (orig :  -31.48   67.48 -255.52 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S07/ses-1/meg/sub-S07_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S07_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S07 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S08/ses-1/meg/sub-S08_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -3.07   63.62    0.00 mm <->   -3.07   63.62    0.00 mm (orig :  -28.39   58.35 -251.23 mm) diff =    0.000 mm
#        3.07  -63.62    0.00 mm <->    3.07  -63.62    0.00 mm (orig :   62.99  -30.39 -249.36 mm) diff =    0.000 mm
#       78.66    0.00    0.00 mm <->   78.66    0.00    0.00 mm (orig :   73.73   66.94 -236.17 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S08/ses-1/meg/sub-S08_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S08_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S08 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S09/ses-1/meg/sub-S09_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.98   71.56    0.00 mm <->   -1.98   71.56    0.00 mm (orig :  -35.75   64.93 -257.10 mm) diff =    0.000 mm
#        1.98  -71.56    0.00 mm <->    1.98  -71.56   -0.00 mm (orig :   64.23  -37.26 -264.99 mm) diff =    0.000 mm
#       70.22    0.00    0.00 mm <->   70.22   -0.00    0.00 mm (orig :   64.50   58.78 -241.46 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S09/ses-1/meg/sub-S09_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S09_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S09 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S10/ses-1/meg/sub-S10_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -2.94   67.17    0.00 mm <->   -2.94   67.17   -0.00 mm (orig :  -36.70   54.37 -257.30 mm) diff =    0.000 mm
#        2.94  -67.17    0.00 mm <->    2.94  -67.17   -0.00 mm (orig :   55.20  -43.64 -251.98 mm) diff =    0.000 mm
#       78.82    0.00    0.00 mm <->   78.82   -0.00    0.00 mm (orig :   68.34   56.58 -244.75 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S10/ses-1/meg/sub-S10_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S10_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S10 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S11/ses-1/meg/sub-S11_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.28   71.06    0.00 mm <->    3.28   71.06   -0.00 mm (orig :  -32.53   62.32 -250.25 mm) diff =    0.000 mm
#       -3.28  -71.06    0.00 mm <->   -3.28  -71.06   -0.00 mm (orig :   60.13  -45.60 -252.86 mm) diff =    0.000 mm
#       89.52    0.00    0.00 mm <->   89.52   -0.00    0.00 mm (orig :   75.48   66.04 -221.85 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S11/ses-1/meg/sub-S11_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S11_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S11 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S12/ses-1/meg/sub-S12_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.64   73.64    0.00 mm <->    2.64   73.64    0.00 mm (orig :  -36.61   63.37 -262.33 mm) diff =    0.000 mm
#       -2.64  -73.64    0.00 mm <->   -2.64  -73.64    0.00 mm (orig :   60.13  -47.80 -262.88 mm) diff =    0.000 mm
#       89.60    0.00    0.00 mm <->   89.60   -0.00    0.00 mm (orig :   77.20   69.00 -263.40 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S12/ses-1/meg/sub-S12_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S12_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S12 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S13/ses-1/meg/sub-S13_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -2.17   70.47    0.00 mm <->   -2.17   70.47   -0.00 mm (orig :  -47.22   50.98 -244.90 mm) diff =    0.000 mm
#        2.17  -70.47    0.00 mm <->    2.17  -70.47   -0.00 mm (orig :   60.19  -40.32 -241.38 mm) diff =    0.000 mm
#       83.97    0.00    0.00 mm <->   83.97   -0.00    0.00 mm (orig :   60.12   65.35 -219.25 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S13/ses-1/meg/sub-S13_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S13_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S13 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S14/ses-1/meg/sub-S14_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.50   80.66    0.00 mm <->   -1.50   80.66    0.00 mm (orig :  -53.83   60.00 -252.29 mm) diff =    0.000 mm
#        1.50  -80.66    0.00 mm <->    1.50  -80.66   -0.00 mm (orig :   64.84  -49.31 -254.16 mm) diff =    0.000 mm
#       93.71    0.00    0.00 mm <->   93.71   -0.00    0.00 mm (orig :   69.14   71.53 -234.44 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S14/ses-1/meg/sub-S14_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S14_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S14 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S15/ses-1/meg/sub-S15_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        1.26   73.66    0.00 mm <->    1.26   73.66   -0.00 mm (orig :  -51.53   56.64 -244.09 mm) diff =    0.000 mm
#       -1.26  -73.66    0.00 mm <->   -1.26  -73.66   -0.00 mm (orig :   51.88  -48.25 -247.76 mm) diff =    0.000 mm
#       84.23    0.00    0.00 mm <->   84.23    0.00    0.00 mm (orig :   57.83   62.37 -226.23 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S15/ses-1/meg/sub-S15_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S15_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S15 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S16/ses-1/meg/sub-S16_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.22   77.44    0.00 mm <->    3.22   77.44   -0.00 mm (orig :  -57.34   57.41 -261.81 mm) diff =    0.000 mm
#       -3.22  -77.44    0.00 mm <->   -3.22  -77.44    0.00 mm (orig :   52.07  -52.30 -266.42 mm) diff =    0.000 mm
#       89.24    0.00    0.00 mm <->   89.23    0.00   -0.00 mm (orig :   57.53   67.29 -251.75 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S16/ses-1/meg/sub-S16_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S16_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S16 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S17/ses-1/meg/sub-S17_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -5.36   72.74    0.00 mm <->   -5.36   72.74    0.00 mm (orig :  -50.91   55.47 -252.77 mm) diff =    0.000 mm
#        5.36  -72.74    0.00 mm <->    5.36  -72.74    0.00 mm (orig :   59.54  -39.84 -252.71 mm) diff =    0.000 mm
#       84.60    0.00    0.00 mm <->   84.60   -0.00    0.00 mm (orig :   62.44   65.68 -232.02 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S17/ses-1/meg/sub-S17_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S17_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S17 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S18/ses-1/meg/sub-S18_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        1.26   72.50    0.00 mm <->    1.26   72.50    0.00 mm (orig :  -36.99   61.25 -276.72 mm) diff =    0.000 mm
#       -1.26  -72.50    0.00 mm <->   -1.26  -72.50    0.00 mm (orig :   60.10  -46.18 -268.78 mm) diff =    0.000 mm
#       85.44    0.00    0.00 mm <->   85.44    0.00    0.00 mm (orig :   73.90   65.95 -272.03 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S18/ses-1/meg/sub-S18_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S18_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S18 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S19/ses-1/meg/sub-S19_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.20   75.55    0.00 mm <->   -0.20   75.55   -0.00 mm (orig :  -45.58   60.72 -255.55 mm) diff =    0.000 mm
#        0.20  -75.55    0.00 mm <->    0.20  -75.55   -0.00 mm (orig :   60.23  -47.00 -250.03 mm) diff =    0.000 mm
#       82.24    0.00    0.00 mm <->   82.24   -0.00    0.00 mm (orig :   66.17   64.09 -257.82 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S19/ses-1/meg/sub-S19_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S19_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S19 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
# ds directory : /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S20/ses-1/meg/sub-S20_ses-1_task-OrientationImagery_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -4.56   70.29    0.00 mm <->   -4.56   70.29   -0.00 mm (orig :  -53.24   48.73 -244.93 mm) diff =    0.000 mm
#        4.56  -70.29    0.00 mm <->    4.56  -70.29   -0.00 mm (orig :   43.19  -53.37 -256.12 mm) diff =    0.000 mm
#       89.71    0.00    0.00 mm <->   89.71    0.00    0.00 mm (orig :   64.19   54.64 -246.83 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /Users/sm6511/Desktop/NIH_Experiment/Bids/sub-S20/ses-1/meg/sub-S20_ses-1_task-OrientationImagery_run-01_meg.ds/sub-S20_ses-1_task-OrientationImagery_run-01_meg.meg4:
#     System clock channel is available, but ignored.
#     1 x 1200000 = 1200000 samples from 320 chs
# Current compensation grade : 3
# Reading 0 ... 1199999  =      0.000 ...   999.999 secs...
#
# S20 run-01 (Dynamic)
#   Total MEG sensors: 269
#   Reference MEG sensors: 28
#   ⚠️ Missing sensors (275): ['M001', 'M002', 'M003', 'M004', 'M005', 'M006', 'M007', 'M008', 'M009', 'M010', 'M011', 'M012', 'M013', 'M014', 'M015', 'M016', 'M017', 'M018', 'M019', 'M020', 'M021', 'M022', 'M023', 'M024', 'M025', 'M026', 'M027', 'M028', 'M029', 'M030', 'M031', 'M032', 'M033', 'M034', 'M035', 'M036', 'M037', 'M038', 'M039', 'M040', 'M041', 'M042', 'M043', 'M044', 'M045', 'M046', 'M047', 'M048', 'M049', 'M050', 'M051', 'M052', 'M053', 'M054', 'M055', 'M056', 'M057', 'M058', 'M059', 'M060', 'M061', 'M062', 'M063', 'M064', 'M065', 'M066', 'M067', 'M068', 'M069', 'M070', 'M071', 'M072', 'M073', 'M074', 'M075', 'M076', 'M077', 'M078', 'M079', 'M080', 'M081', 'M082', 'M083', 'M084', 'M085', 'M086', 'M087', 'M088', 'M089', 'M090', 'M091', 'M092', 'M093', 'M094', 'M095', 'M096', 'M097', 'M098', 'M099', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275']
